# %%
import pandas as pd

# %%
df=pd.read_csv("/content/twitter_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# %%
import re
import nltk
nltk.download("stopwords")
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
ps = PorterStemmer()
stop = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df["labels"] = df["class"].map({0:"Hate Speech Dtetcted",1:"Offensive Language Detected",2:"Offensive Language Detected",3:"No Hate or offensive Speech Detected"})

# %%
df.head()
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet  \
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
#
#                         labels
# 0  Offensive Language Detected
# 1  Offensive Language Detected
# 2  Offensive Language Detected
# 3  Offensive Language Detected
# 4  Offensive Language Detected

# %%
print(df["tweet"])
# Out:
# 0        !!! RT @mayasolovely: As a woman you shouldn't...
# 1        !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2        !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3        !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4        !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
#                                ...
# 24778    you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779    you've gone and broke the wrong heart baby, an...
# 24780    young buck wanna eat!!.. dat nigguh like I ain...
# 24781                youu got wild bitches tellin you lies
# 24782    ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
# Name: tweet, Length: 24783, dtype: object

# %%
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

def clean(text):
    # Convert text to lowercase
    text = str(text).lower()

    # Remove special characters, URLs, and square brackets
    text = re.sub(r"[^\w\s]", " ", text)
    text = re.sub(r"https\S+|http\S+|www\S+", " ", text)
    text = re.sub(r"\[.*?\]", " ", text)
    text = re.sub("<.*>", " ", text)

    # Remove hashtags and newlines
    text = re.sub("#\w+", " ", text)
    text = re.sub("\n", " ", text)
    text = text.replace('_',' ')
    # Tokenize the text and apply stemming while removing stopwords
    ps = PorterStemmer()
    stop_words = set(stopwords.words("english"))
    words = word_tokenize(text)
    words = [ps.stem(word) for word in words if word not in stop_words]

    # Join the stemmed words back into a single string
    text = ' '.join(words)

    return text

# %%
df["tweet"] = df["tweet"].apply(clean)

# %%
df.head()
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet  \
# 0  rt mayasolov woman complain clean hous amp man...
# 1  rt mleew17 boy dat cold tyga dwn bad cuffin da...
# 2  rt urkindofbrand dawg rt 80sbaby4lif ever fuck...
# 3         rt c g anderson viva base look like tranni
# 4  rt shenikarobert shit hear might true might fa...
#
#                         labels
# 0  Offensive Language Detected
# 1  Offensive Language Detected
# 2  Offensive Language Detected
# 3  Offensive Language Detected
# 4  Offensive Language Detected

# %%
cv = CountVectorizer()

# %%
n = np.array(df["tweet"])
x=cv.fit_transform(n)
x
# Out:
# <24783x31086 sparse matrix of type '<class 'numpy.int64'>'
# 	with 225051 stored elements in Compressed Sparse Row format>

# %%
import numpy as np

y=np.array(df["labels"])
y
# Out:
# array(['Offensive Language Detected', 'Offensive Language Detected',
#        'Offensive Language Detected', ..., 'Offensive Language Detected',
#        'Offensive Language Detected', 'Offensive Language Detected'],
#       dtype=object)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=42)

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
ypred = clf.predict(x_test)

from sklearn.metrics import accuracy_score
accuracy_score(y_test,ypred)
# Out:
# 0.9270081917104781
